# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ilk veri

# %%
df = pd.read_excel("C:/Users/aysen/Downloads/excelfiletemp.xlsx")

# %%
df
# Out:
#                                     Temp
# Time
# 00:00:00.000                       125.0
# 00:00:00.050                       125.0
# 00:00:00.100                       125.0
# 00:00:00.150                       125.0
# 00:00:00.200                       125.0
# ...                                  ...
# 00:00:23.250                       125.0
# 00:00:23.300                       125.0
# 00:00:23.350                       125.0
# ---------------------------------    NaN
# End of File                          NaN
#
# [470 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Time', 'Temp'], dtype='object')

# %%
df = df.set_index("Time")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (10,6))
sns.lineplot(y = df["Temp"], x = df.index, data = df)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Temp'>

# %%
df.columns
# Out:
# Index(['Temp'], dtype='object')

# %%
df.describe()
# Out:
#              Temp
# count  468.000000
# mean   254.960470
# std    127.619461
# min    125.000000
# 25%    125.000000
# 50%    310.950000
# 75%    382.700000
# max    399.300000

# %% [markdown]
# # ikinci veri

# %%
data = pd.read_excel("C:/Users/aysen/Downloads/tempdata2.xlsx")

# %%
data = data[:-2]

# %%
data
# Out:
#               Time  Area 1  Area 2  Area 3
# 0     00:00:00.000    57.3    48.9    56.3
# 1     00:00:00.050    57.3    48.9    56.3
# 2     00:00:00.100    57.3    48.9    56.3
# 3     00:00:00.150    57.3    48.9    56.3
# 4     00:00:00.200    57.3    48.9    56.3
# ...            ...     ...     ...     ...
# 997   00:00:49.850    56.2    47.7    55.1
# 998   00:00:49.900    56.6    47.5    55.1
# 999   00:00:49.950    56.4    47.1    55.6
# 1000  00:00:50.000    56.4    46.8    54.7
# 1001  00:00:50.050    56.6    47.2    55.0
#
# [1002 rows x 4 columns]

# %%
plt.figure(figsize = (14,6))
sns.lineplot(y = data["Area 1"], x = data["Time"], data = data)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area 1'>

# %%
plt.figure(figsize = (16,10))
plt.plot(vis_data["Area 1"], label = "Area 1")
plt.plot(vis_data["Area 2"], label = "Area 2")
plt.plot(vis_data["Area 3"], label = "Area 3")
plt.legend()
plt.show()

# %%
#23. saniyelerde değişmeye başlıyorlar. Toplam 50 saniye

# %%
#correlations
data.corr()
# Out:
#           Area 1    Area 2    Area 3
# Area 1  1.000000  0.129319  0.189801
# Area 2  0.129319  1.000000  0.308850
# Area 3  0.189801  0.308850  1.000000

# %%
# Compute the correlation matrix
corr = data.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#             Area 1       Area 2       Area 3
# count  1002.000000  1002.000000  1002.000000
# mean     57.003792    48.545409    55.778842
# std       1.099453     0.816295     0.658542
# min      47.600000    46.200000    52.000000
# 25%      57.000000    48.125000    55.400000
# 50%      57.300000    48.900000    56.000000
# 75%      57.300000    48.900000    56.300000
# max      58.300000    54.200000    57.200000
